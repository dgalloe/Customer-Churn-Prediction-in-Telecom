# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario del estudiante</b> <a class="tocSkip"></a>
#
# <b>Informe de solución:</b>
#
# <b>Paso 1 Limpieza y Preparación de datos: </b>
# Se realizó toda la revisión y estructuración de los 4 datasets para poder realizar un buen análisis exploratorio.
# - Se revisó la estructura de este Dataframe, que cuenta con 7043 filas y 8 columnas.
# - Se modificó la estructura de los nombres de las columnas para que estuvieran en minúscula y los nombres compuestos fueran separados por un guion bajo.
# - No se presentan datos duplicados ni valores ausentes.
# - Se encontraron datos en blanco en 11 filas en la columna 'total_charges', se tomó la decisión de reemplazar estos valores por la mediana de esta columna.
# - No se puede reemplazar los valores 'No' en la columna 'end_date', ya que esta es la columna objetivo.
# - Se corrigieron los tipos de datos de las columnas con fechas y con valores decimales.
#
# <b>Paso 2 Análisis Exploratorio Profundo: </b>
#
# Se preparo todos un análisis que aportara encontrar patrones, distribuciones, comportamientos y datos claves del comportamiento de los clientes. Se generaron preguntas claves que permitieran resolver dudas y mejorar el entendimiento del negocio. Se propuso reuniones con el equipo de Marketing para presentar estos hallazgos y profundizar en el análisis:
#
# - Los gráficos realizados para la columna begin_date muestran que la compañía obtuvo la mayor cantidad de sus clientes en los meses de Febrero, Marzo y Abril de 2014, y en el último trimestre de 2019 y Enero de 2020. Estos meses muestran comportamientos atípicos en la obtención de clientes y vale la pena preguntar qué sucedió en dichos periodos de tiempo para obtener tantos clientes:
# ¿Se realizaron campañas de obtención de clientes diferentes y más agresivas?
# ¿Se lanzaron nuevos productos / servicios al mercado?
# ¿Qué permitió obtener esa cantidad de clientes en esos meses?
#
# - El gráfico realizado para la columna end_date muestra se han presentado 4 periodos donde algunas clientes han cancelado su suscripción a la empresa. ¿Qué ha sucedido en estos 4 meses que han generado el retiro de los clientes? ¿Se han realizado encuestas para intentar encontrar por que se han ido estos clientes?
#
# - Se observa que la mayoría de los clientes tienen un contrato mes a mes, financieramente puede ser más interesante tener contratos mes a mes porque los contratos anuales pueden tener más descuentos.
# ¿Qué estrategias podría aplicar la compañía para que aumentaran los clientes con contrato a 1 y 2 años?
# ¿Cómo podrían fidelizar aún más los clientes para tener contratos diferentes al mes a mes?
#
# - Se observa que los clientes que más han cancelado han sido los que tienen contratos mes a mes. Sería interesante crear campañas de fidelización y descuentos especiales para clientes con contratos mes a mes para pasar a contratos anuales.
#
# - Entre los clientes que han cancelado predomina los que tienen Electronic Check.
#
# - Al comparar la estadística descriptiva e histograma de los cargos mensuales versus los cargos mensuales de los contratos cancelados, se encuentra que estos últimos tienen una media y mediana superiores a los primeros, por lo tanto, los clientes que han cancelado eran clientes más rentables que todos los clientes de la compañía. Perder estos clientes ha afectado los ingresos promedio de la compañía.
#
# - Al realizar la misma comparación anterior, pero para la columna 'total_charges', se encuentra que los clientes cancelados tienen una media y mediana inferior al dataset con todos los clientes, esto es lo opuesto a la que muestra la columna 'montlhy_charges'. Sería interesante comprender por qué se presenta este comportamiento.
#
# - Al analizar las distribuciones de los pagos mensuales de los contratos cancelados por tipo de contrato (mes a mes, anual y bianual), se encuentra que estás distribuciones están sesgadas a la izquierda (media < mediana). Esto confirma la premisa de que los clientes que cancelaron los contratos eran clientes que en su mayoría eran clientes buenos con un ticket medio superior a los demás clientes.
#
# - Al analizar las agrupaciones por 'Gender', 'Senior Citizen', 'Partner' y 'Dependents' de los clientes que cancelaron el contrato no se encuentra diferencias o patrones considerables con respecto al dataset total. Por ejemplo, se esperaría que los clientes que cancelaron fueran en su mayoría clientes con personas a cargo (dependents), los cuales por cuestiones económicas pudieran haber optimizado servicios o contrato con la competencia por un menor precio, pero este no es el caso. La mayoría de los clientes que han cancelado el contrato no son Senior Citizen, no tienen Partner' y no tienen Dependents. Tampoco se encuentra que un género haya cancelado más que otro.
#
# - Se agruparon todos los datasets y no existen clientes que no tenga algún producto, por esta razón no pueden eliminar filas.
#
# - Llama la atención que la mayoría de los clientes que han cancelado tenían el servicio de fibra óptica, ¿Se ha estudiado a qué se debe esto? La compañía presenta mayor cantidad de clientes activos en el servicio de Internet DSL, ¿Interconnect tiene mayor presencia en zonas rurales donde no hay redes de Fibra Óptica?
#
# - Se realizó gráfico de barras agrupado para observar cómo era la distribución de los clientes activos y cancelados por tipo de servicio de Internet. En los clientes activos, las barras de la cantidad de clientes con y sin servicios adicionales de internet no presenta muchas diferencias. Por su parte, los clientes que han cancelado contaban con menos servicios de Internet (gráfico 'Cancelled clients by Internet Services').
#
# - ¿En el gráfico (‘Number of active clients with Multiples lines’) se observa que la mayoría de los clientes con los que cuenta la compañía no tienen múltiples líneas de teléfono, esto está relacionado con que la compañía tenga mayores clientes con servicio de Internet DSL? DSL solo requiere de una línea de teléfono. Como se observa en el gráfico 'Number of active clients with Multiples lines & DSL internet service'.
#
# - Por qué cancelan más clientes que tienen el servicio de Fibra Óptica? ¿Están en ciudades grandes donde la competencia es mayor? ¿la competencia ofrece un internet más rápido y a menos costo? ¿por qué las cancelaciones son en 4 meses específicos, ocurrió algún inconveniente con el servicio en esos meses?
#
# - Revisando la mediana de las columnas monthly_charges y total_charges para los clientes activos y cancelados con servicio de Internet DSL y Fibra Óptica, encontramos que los clientes que tienen pagos más altos y por ende, más rentables e importantes para la compañía, son los de Fibra Óptica.
#
# - ¿Los clientes sin servicios de internet deben considerarse como un segmento especial o integrarlos al análisis general?
#
# <b>Paso 3 Ingeniería de características: </b>
#
# Se creo una variable derivada llamada 'total_services' que permitía identificar la totalidad de servicios por cliente, teniendo en cuenta que la empresa ofrece diferentes servicios. Encontramos que del total de clientes que cancelaron, la distribución de estos clientes se concentraba en baja cantidad de productos, indicando que entre más productos tuvieran los clientes, menos cancelaciones se presentaban.
#
# <b>Paso 4 Modelado y evaluación: </b>
#
# Se entrenaron 3 modelos (RandomForestClassifier, DecisionTreeClassifier, LGBMClassifier) para evaluar cuál de los 3 presentaba el mejor rendimiento bajo las métricas AUC-ROC, Recall y Precision.
# Se modificaron hiperparámetros y desbalances de clases para mejorar el rendimiento de los modelos.
#
# <b>Paso 5 Interpretación y recomendaciones: </b>
#
# - El modelo con el mejor AUC-ROC, 0.837635524344385, fue Random Forest Classifier con ajuste de hiperparámetros (200 estimadores, 10 máximo profundidad, 5 split y 4 leaf).
# - Este modelo logró un Recall máximo de 0.901 y una Precisión de 0.452, bajo el umbral 0.3.
#
# Random Forest adjusted parameters AUC-ROC: 0.837635524344385
#
# Umbral 0.3: Recall=0.901, Precision=0.452
#
# Umbral 0.35: Recall=0.873, Precision=0.476
#
# Umbral 0.4: Recall=0.835, Precision=0.496
#
# Umbral 0.45: Recall=0.785, Precision=0.515
#
# Umbral 0.5: Recall=0.734, Precision=0.543
#
# - Argumento mi decisión en la escogencia de este modelo bajo la métrica RECALL, la cual nos ayuda a identificar el 90% de los clientes con probabilidad de cancelar, y esto es de vital importancia para esta empresa, porque el objetivo del modelo es identificar a los clientes que tienen alguna probabilidad de cancelar los servicios con la empresa y de esta forma evitar que se vayan. La Precisión del modelo, para un Recall de 0.901, es 0.452, indicando que del total de clientes identificados como clientes que cancelaran, solo cancelan 0.452 (45%).
# - Aunque deseáramos que el modelo tuviera una precisión de 100%, también tenemos que pensar en si la empresa tiene la capacidad para contactar y ofrecer soluciones para el 100% de los clientes que van a cancelar, puesto que lograr esto, implica tener unos costos elevados en atención al cliente y en negociación de estímulos o mejores condiciones para dichos clientes.
# - Este modelo permite que la compañía defina el objetivo de la cantidad de clientes que desea retener y por ejemplo, bajo el umbral 0.5, el RECALL baja a 0.734, se identifican al 73% de los clientes que van a cancelar, de los cuales el 54.3% (Precisión 0.543) verdaderamente cancelan.
# - En el proceso se generarán falsos positivos (clientes que se predicen van a cancelar y que no lo hacen, esto lo genera la diferencia entre RECALL y PRECISION). Sin embargo, no veo la generación de FALSOS POSITIVOS como algo negativo, por el contrario, la compañía puede aprovechar estos falsos positivos para contactarlos e escucharlos, pudiendo detectar el sentimiento de estos clientes con la empresa.
# - La compañía debe definir el objetivo de clientes a retener y los que permitirá que se vayan de la compañía, siempre teniendo en cuenta el presupuesto de la compañía para este proceso. Este modelo prioriza no perder clientes reales sobre la precisión. Es más costoso perder un cliente para la compañía, que contactar a clientes que no se irán (falsos positivos).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# 🎓 <b>¡Felicidades por finalizar el bootcamp!</b><br><br>
#
# Tu trabajo ha sido **excepcional**. Este proyecto final demuestra un dominio sólido en análisis exploratorio, ingeniería de características, modelado supervisado y, sobre todo, en **interpretación estratégica de resultados**, lo cual es clave para aportar valor real en entornos empresariales.
#
# 👏 **Éxitos destacados**:
#
# * Tu EDA fue profundo, con preguntas críticas y enfoque orientado al negocio.
# * La justificación del modelo basada en Recall es muy acertada para un caso de churn.
# * Mostraste conciencia del costo-beneficio al balancear Recall y Precision.
# * Aplicaste correctamente selección de modelos, ajuste de hiperparámetros y manejo del desbalanceo de clases.
#
# 🧭 **Recomendaciones para el futuro**:
#
# 1. **Integra tus proyectos en un portafolio online** (por ejemplo, GitHub o un sitio personal). Explica cada caso como si fuera para un cliente no técnico.
# 2. **Practica storytelling con datos**: Aprende a comunicar insights en presentaciones visuales (Power BI, Tableau o dashboards interactivos en Streamlit).
# 3. **Explora temas avanzados**, como:
#
#    * Modelos de clasificación interpretables (SHAP, LIME).
#    * Implementación de pipelines de ML con `scikit-learn` o `mlflow`.
#    * Validación cruzada estratificada y experimentación con AutoML.
# 4. **Complementa con conocimiento de negocio**: Saber de marketing, ventas o retención te permitirá aplicar modelos con aún más impacto.
# 5. **Aprende sobre deployment**: Flask, FastAPI, Streamlit o herramientas como AWS Sagemaker te ayudarán a poner modelos en producción.
#
# ¡Mucho éxito en tu camino profesional! 🚀📈💼
#
# </div>
